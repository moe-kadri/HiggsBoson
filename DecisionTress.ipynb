# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, StratifiedKFold, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pickle
from sklearn.metrics import confusion_matrix

# Load the Higgs dataset
df = pd.read_csv('HIGGS_train.csv', header=None, low_memory=False)
df.dropna(inplace=True)

# Separate the target variable and features
X = df.iloc[:, 1:]
y = df.iloc[:, 0]


# Dimensionality reduction
pca = PCA(n_components=10, random_state=42)
X_pca = pca.fit_transform(X)

# Use a more efficient data structure
X_pca = np.array(X_pca)
y = np.array(y)

# Preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_pca)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Define decision tree parameters
dt_params = {'max_depth': [5, 10 ,15],
             'criterion': ['gini','entropy'],
             'splitter': ['random','best'],
             'random_state': [42]}

# Define random forest parameters
rf_params = {'n_estimators': [5, 10, 15],
             'max_depth': [5, 10],
             'criterion': ['entropy'],
             'random_state': [42]}

# Define XGBoost parameters
xgb_params = {'max_depth': [5, 10, 15],
              'learning_rate': [0.01, 0.1],
              'n_estimators': [5, 10],
              'random_state': [42]}

# Define the different cross-validation methods
kf = KFold(n_splits=5, shuffle=True, random_state=42)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = {}
best_models = {}

for model_name, model, params in [('Decision Tree', DecisionTreeClassifier(), dt_params),
                                  ('Random Forest', RandomForestClassifier(), rf_params),
                                  ('XGBoost', XGBClassifier(), xgb_params)]:
    model_results = []
    print(f'{model_name}:')
    for param_set in GridSearchCV(model, params, cv=skf, scoring='accuracy').fit(X_train, y_train).cv_results_['params']:
        print(f'Parameters: {param_set}')
        for cv_method in ['KFold', 'StratifiedKFold']:
            if cv_method == 'KFold':
                cv = kf
            else:
                cv = skf
            for metric in ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']:
                print(f'Cross-validation method: {cv_method}')
                print(f'Scoring metric: {metric}')
                scores = cross_val_score(model.set_params(**param_set), X_train, y_train, cv=cv, scoring=metric, n_jobs=-1)
                model_results.append((cv_method, metric, scores.mean()))
                
                # Print the confusion matrix
                clf = model.set_params(**param_set).fit(X_train, y_train)
                y_pred = clf.predict(X_test)
                cm = confusion_matrix(y_test, y_pred)
                print(f'Confusion matrix: \n{cm}')
                
                print(f'{metric} score: {scores.mean()}')
                print("\n")
        
        # Save the best model for this category
        if model_name not in best_models:
            best_models[model_name] = model.set_params(**param_set)
        else:
            old_scores = cross_val_score(best_models[model_name], X_train, y_train, cv=skf, scoring='accuracy', n_jobs=-1)
            new_scores = cross_val_score(model.set_params(**param_set), X_train, y_train, cv=skf, scoring='accuracy', n_jobs=-1)
            if new_scores.mean() > old_scores.mean():
                best_models[model_name] = model.set_params(**param_set)

    results[model_name] = model_results
    print('\n')
    
# Save the best models using pickle
for model_name, model in best_models.items():
    with open(f'{model_name}_best_model.pkl', 'wb') as f:
        pickle.dump(model, f)
        print(f'Saved {model_name} best model')

print('\n')
print('Results:')
for model_name, model_results in results.items():
    print(f'{model_name}:')
    for cv_method, metric, score in model_results:
        print(f'CV method: {cv_method}, Metric: {metric}, Score: {score:.6f}')
# Out:
# Decision Tree:
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# accuracy score: 0.5473372520874682
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# precision_macro score: 0.5440363908214219
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# recall_macro score: 0.5331093878144889
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# f1_macro score: 0.5090128368652571
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# accuracy score: 0.5457991333230157
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# precision_macro score: 0.5426650551874336
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# recall_macro score: 0.530440851325342
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[23689 60861]
#  [20844 74606]]
# f1_macro score: 0.5017967764964029
#
#
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# accuracy score: 0.559399229355905
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# precision_macro score: 0.5886848125847701
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# recall_macro score: 0.5378632914789763
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# f1_macro score: 0.47277573109884824
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# accuracy score: 0.5599682772300577
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# precision_macro score: 0.5865395715025062
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# recall_macro score: 0.5393428178630026
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15232 69318]
#  [ 9534 85916]]
# f1_macro score: 0.479653913152306
#
#
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# accuracy score: 0.5696326364429509
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# precision_macro score: 0.5709022784197337
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# recall_macro score: 0.5573377587519726
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# f1_macro score: 0.5416754188871613
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# accuracy score: 0.5689921485176411
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# precision_macro score: 0.5692277800607337
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# recall_macro score: 0.5574152846409384
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[27960 56590]
#  [21765 73685]]
# f1_macro score: 0.5439024111126013
#
#
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# accuracy score: 0.5805089038474949
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# precision_macro score: 0.5821339473845508
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# recall_macro score: 0.5694219197928186
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# f1_macro score: 0.5578781694875949
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# accuracy score: 0.5799946232920007
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# precision_macro score: 0.5837343470132367
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# recall_macro score: 0.5676359073877844
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[30109 54441]
#  [20511 74939]]
# f1_macro score: 0.55221003639179
#
#
# Parameters: {'criterion': 'gini', 'max_depth': 15, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# accuracy score: 0.5777207880309233
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# precision_macro score: 0.5755794799856173
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# recall_macro score: 0.569913168252852
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# f1_macro score: 0.565385406980081
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# accuracy score: 0.5754564952587304
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# precision_macro score: 0.5732771147032726
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# recall_macro score: 0.5674163866737658
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[35510 49040]
#  [27256 68194]]
# f1_macro score: 0.5623594058016039
#
#
# Parameters: {'criterion': 'gini', 'max_depth': 15, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# accuracy score: 0.583401774114091
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# precision_macro score: 0.5821080819469578
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# recall_macro score: 0.5750376465431876
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# f1_macro score: 0.5697386567497567
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# accuracy score: 0.5840422679918525
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# precision_macro score: 0.5832352276745041
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# recall_macro score: 0.575420542999139
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37373 47177]
#  [26958 68492]]
# f1_macro score: 0.5693977749496806
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# accuracy score: 0.5473372520874682
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# precision_macro score: 0.5440363908214219
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# recall_macro score: 0.5331093878144889
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# f1_macro score: 0.5090128368652571
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# accuracy score: 0.5434872010381075
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# precision_macro score: 0.5398870842528145
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# recall_macro score: 0.5266016872056403
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[23315 61235]
#  [20466 74984]]
# f1_macro score: 0.48802883738295016
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# accuracy score: 0.5584230389647497
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# precision_macro score: 0.5940764947162642
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# recall_macro score: 0.536173439887013
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# f1_macro score: 0.46487998645912576
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# accuracy score: 0.5597087508127931
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# precision_macro score: 0.586540922430735
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# recall_macro score: 0.5390081030289068
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15231 69319]
#  [ 9535 85915]]
# f1_macro score: 0.47875905193699275
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# accuracy score: 0.5691921586368092
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# precision_macro score: 0.5683605280427126
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# recall_macro score: 0.5583894065816825
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# f1_macro score: 0.5472502806027136
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# accuracy score: 0.5694754833532598
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# precision_macro score: 0.5700094561210068
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# recall_macro score: 0.5577255886290936
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25227 59323]
#  [17588 77862]]
# f1_macro score: 0.5437218245976482
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# accuracy score: 0.5795017619824272
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# precision_macro score: 0.580282499095216
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# recall_macro score: 0.5689131037841589
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# f1_macro score: 0.5585771806701095
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# accuracy score: 0.5790279523452376
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# precision_macro score: 0.5819899389707262
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# recall_macro score: 0.5670038049366524
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[29620 54930]
#  [20001 75449]]
# f1_macro score: 0.5524652728225321
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 15, 'random_state': 42, 'splitter': 'random'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# accuracy score: 0.5772993682464473
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# precision_macro score: 0.5755210945462299
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# recall_macro score: 0.5689783809379259
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# f1_macro score: 0.5634405263177894
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# accuracy score: 0.5761922052926934
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# precision_macro score: 0.5746316505747217
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# recall_macro score: 0.5672252307144743
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[33658 50892]
#  [25069 70381]]
# f1_macro score: 0.5606063499053043
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 15, 'random_state': 42, 'splitter': 'best'}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# accuracy score: 0.5834113124079143
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# precision_macro score: 0.5824202887112501
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# recall_macro score: 0.5746934520645197
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# f1_macro score: 0.5687192530112906
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# accuracy score: 0.5851446660362737
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# precision_macro score: 0.5844449282576522
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# recall_macro score: 0.5764666249936854
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37128 47422]
#  [26497 68953]]
# f1_macro score: 0.5704234672280577
#
#
#
#
# Random Forest:
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# accuracy score: 0.5609920959943401
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# precision_macro score: 0.5874878695436966
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# recall_macro score: 0.5398451935743537
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# f1_macro score: 0.47847979622224057
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# accuracy score: 0.5641254653541794
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# precision_macro score: 0.5813501906984795
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# recall_macro score: 0.5452127919295904
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[17691 66859]
#  [11688 83762]]
# f1_macro score: 0.49852885185023493
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# accuracy score: 0.5594706608752145
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# precision_macro score: 0.5952157451738783
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# recall_macro score: 0.5370320681307325
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# f1_macro score: 0.46521709211856355
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# accuracy score: 0.5616825857620754
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# precision_macro score: 0.5917983643705201
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# recall_macro score: 0.5401529273639344
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[12313 72237]
#  [ 7040 88410]]
# f1_macro score: 0.4759982062015474
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 15, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# accuracy score: 0.5603754294410533
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# precision_macro score: 0.6005565986077182
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# recall_macro score: 0.5376532199353835
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# f1_macro score: 0.4636302765518314
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# accuracy score: 0.5614135359321171
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# precision_macro score: 0.597543582470917
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# recall_macro score: 0.5392094867410162
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[12164 72386]
#  [ 6827 88623]]
# f1_macro score: 0.4696552382163245
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# accuracy score: 0.5826898724984821
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# precision_macro score: 0.590903742275144
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# recall_macro score: 0.5686481265399633
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# f1_macro score: 0.5479660616159501
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# accuracy score: 0.5857541809171198
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# precision_macro score: 0.5953485151841307
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# recall_macro score: 0.5715968403051478
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25621 58929]
#  [16158 79292]]
# f1_macro score: 0.5505232262031473
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# accuracy score: 0.5868875255317665
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# precision_macro score: 0.598824076964845
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# recall_macro score: 0.5720730292480735
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# f1_macro score: 0.548935682541046
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# accuracy score: 0.5881375315409083
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# precision_macro score: 0.6006164501243977
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# recall_macro score: 0.5733235071562734
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25697 58853]
#  [15113 80337]]
# f1_macro score: 0.5501708760401536
#
#
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 15, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# accuracy score: 0.5879756283946691
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# precision_macro score: 0.6015769352092014
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# recall_macro score: 0.5728024244262281
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# f1_macro score: 0.5483606880539387
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# accuracy score: 0.5886303964786428
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# precision_macro score: 0.603051973857886
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# recall_macro score: 0.5733339600901902
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[25206 59344]
#  [14486 80964]]
# f1_macro score: 0.5483900434782442
#
#
#
#
# XGBoost:
# Parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# accuracy score: 0.5615254393334614
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# precision_macro score: 0.5893564927545027
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# recall_macro score: 0.5404708433045378
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# f1_macro score: 0.47957603760015777
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# accuracy score: 0.5607325758980124
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# precision_macro score: 0.589623706376762
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# recall_macro score: 0.539446890039504
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15537 69013]
#  [ 9684 85766]]
# f1_macro score: 0.4765798645243778
#
#
# Parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# accuracy score: 0.5615444868674742
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# precision_macro score: 0.5893973982496534
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# recall_macro score: 0.5404919768762345
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# f1_macro score: 0.4796137891661722
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# accuracy score: 0.5608301946054913
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# precision_macro score: 0.5928372388272056
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# recall_macro score: 0.5392198648527875
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[15570 68980]
#  [ 9718 85732]]
# f1_macro score: 0.4738331962643542
#
#
# Parameters: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# accuracy score: 0.5836255861889512
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# precision_macro score: 0.5875231680724582
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# recall_macro score: 0.57151716393765
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# f1_macro score: 0.5574158447517377
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# accuracy score: 0.5826041506729955
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# precision_macro score: 0.5860959276486113
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# recall_macro score: 0.5706095972016574
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31914 52636]
#  [21960 73490]]
# f1_macro score: 0.5567753626983014
#
#
# Parameters: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# accuracy score: 0.5879518216203254
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# precision_macro score: 0.5929015499513284
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# recall_macro score: 0.5757283446636627
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# f1_macro score: 0.5615905256245657
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# accuracy score: 0.5861898978672648
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# precision_macro score: 0.5906251881882396
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# recall_macro score: 0.5741193415966933
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[30535 54015]
#  [20069 75381]]
# f1_macro score: 0.5602091880004405
#
#
# Parameters: {'learning_rate': 0.01, 'max_depth': 15, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# accuracy score: 0.5876470433604936
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# precision_macro score: 0.5869936489341141
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# recall_macro score: 0.5790464795434541
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# f1_macro score: 0.57344440378866
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# accuracy score: 0.5875756270624537
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# precision_macro score: 0.5873407495817179
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# recall_macro score: 0.5787215889033767
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37229 47321]
#  [26071 69379]]
# f1_macro score: 0.572444947584222
#
#
# Parameters: {'learning_rate': 0.01, 'max_depth': 15, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# accuracy score: 0.5917351690411281
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# precision_macro score: 0.5915513176927234
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# recall_macro score: 0.5831182380483382
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# f1_macro score: 0.5775944248407018
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# accuracy score: 0.5913137425955751
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# precision_macro score: 0.591613581961514
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# recall_macro score: 0.5823778597089896
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37308 47242]
#  [25694 69756]]
# f1_macro score: 0.5761458767520184
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# accuracy score: 0.5640183190672905
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# precision_macro score: 0.5970273516432807
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# recall_macro score: 0.5425323041360184
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# f1_macro score: 0.4791244517326227
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# accuracy score: 0.5645373654675028
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# precision_macro score: 0.5979164321054488
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# recall_macro score: 0.543109905011341
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[14913 69637]
#  [ 8261 87189]]
# f1_macro score: 0.480075405260851
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# accuracy score: 0.5680683461084286
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# precision_macro score: 0.6023281135813029
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# recall_macro score: 0.5469793422597606
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# f1_macro score: 0.48723450578115096
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# accuracy score: 0.5687231067376652
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# precision_macro score: 0.6029050539272454
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# recall_macro score: 0.5477301486371402
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[16950 67600]
#  [ 9360 86090]]
# f1_macro score: 0.4887451975687124
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# accuracy score: 0.5932090006740444
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# precision_macro score: 0.5990958051117001
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# recall_macro score: 0.5811094523234906
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# f1_macro score: 0.5675831182228919
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# accuracy score: 0.5931113756456284
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# precision_macro score: 0.5987795999970753
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# recall_macro score: 0.5810900525274134
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31700 52850]
#  [20123 75327]]
# f1_macro score: 0.5678111530176189
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# accuracy score: 0.5973590270915924
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# precision_macro score: 0.6041735061493934
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# recall_macro score: 0.5852659408460203
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# f1_macro score: 0.5719905592673223
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# accuracy score: 0.5984209399034797
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# precision_macro score: 0.605314375701642
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# recall_macro score: 0.5863898290369611
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[31906 52644]
#  [19720 75730]]
# f1_macro score: 0.5733491701166886
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 15, 'n_estimators': 5, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# accuracy score: 0.598142368134768
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# precision_macro score: 0.5985211700259341
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# recall_macro score: 0.5896251004827154
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# f1_macro score: 0.5844366880315424
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# accuracy score: 0.5994042808616202
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# precision_macro score: 0.6000809875062074
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# recall_macro score: 0.5907886218414604
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[37388 47162]
#  [24575 70875]]
# f1_macro score: 0.5854378935296989
#
#
# Parameters: {'learning_rate': 0.1, 'max_depth': 15, 'n_estimators': 10, 'random_state': 42}
# Cross-validation method: KFold
# Scoring metric: accuracy
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# accuracy score: 0.6056019435605526
#
#
# Cross-validation method: KFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# precision_macro score: 0.6065062768892215
#
#
# Cross-validation method: KFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# recall_macro score: 0.5972830430391298
#
#
# Cross-validation method: KFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# f1_macro score: 0.5926084067406492
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: accuracy
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# accuracy score: 0.6063281427953507
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: precision_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# precision_macro score: 0.6073131814152923
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: recall_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# recall_macro score: 0.598023242432155
#
#
# Cross-validation method: StratifiedKFold
# Scoring metric: f1_macro
# Confusion matrix:
# [[38744 45806]
#  [24422 71028]]
# f1_macro score: 0.5933750966822994
#
#
#
#
# Saved Decision Tree best model
# Saved Random Forest best model
# Saved XGBoost best model
#
#
# Results:
# Decision Tree:
# CV method: KFold, Metric: accuracy, Score: 0.547337
# CV method: KFold, Metric: precision_macro, Score: 0.544036
# CV method: KFold, Metric: recall_macro, Score: 0.533109
# CV method: KFold, Metric: f1_macro, Score: 0.509013
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.545799
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.542665
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.530441
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.501797
# CV method: KFold, Metric: accuracy, Score: 0.559399
# CV method: KFold, Metric: precision_macro, Score: 0.588685
# CV method: KFold, Metric: recall_macro, Score: 0.537863
# CV method: KFold, Metric: f1_macro, Score: 0.472776
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.559968
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.586540
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.539343
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.479654
# CV method: KFold, Metric: accuracy, Score: 0.569633
# CV method: KFold, Metric: precision_macro, Score: 0.570902
# CV method: KFold, Metric: recall_macro, Score: 0.557338
# CV method: KFold, Metric: f1_macro, Score: 0.541675
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.568992
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.569228
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.557415
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.543902
# CV method: KFold, Metric: accuracy, Score: 0.580509
# CV method: KFold, Metric: precision_macro, Score: 0.582134
# CV method: KFold, Metric: recall_macro, Score: 0.569422
# CV method: KFold, Metric: f1_macro, Score: 0.557878
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.579995
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.583734
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.567636
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.552210
# CV method: KFold, Metric: accuracy, Score: 0.577721
# CV method: KFold, Metric: precision_macro, Score: 0.575579
# CV method: KFold, Metric: recall_macro, Score: 0.569913
# CV method: KFold, Metric: f1_macro, Score: 0.565385
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.575456
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.573277
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.567416
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.562359
# CV method: KFold, Metric: accuracy, Score: 0.583402
# CV method: KFold, Metric: precision_macro, Score: 0.582108
# CV method: KFold, Metric: recall_macro, Score: 0.575038
# CV method: KFold, Metric: f1_macro, Score: 0.569739
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.584042
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.583235
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.575421
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.569398
# CV method: KFold, Metric: accuracy, Score: 0.547337
# CV method: KFold, Metric: precision_macro, Score: 0.544036
# CV method: KFold, Metric: recall_macro, Score: 0.533109
# CV method: KFold, Metric: f1_macro, Score: 0.509013
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.543487
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.539887
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.526602
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.488029
# CV method: KFold, Metric: accuracy, Score: 0.558423
# CV method: KFold, Metric: precision_macro, Score: 0.594076
# CV method: KFold, Metric: recall_macro, Score: 0.536173
# CV method: KFold, Metric: f1_macro, Score: 0.464880
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.559709
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.586541
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.539008
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.478759
# CV method: KFold, Metric: accuracy, Score: 0.569192
# CV method: KFold, Metric: precision_macro, Score: 0.568361
# CV method: KFold, Metric: recall_macro, Score: 0.558389
# CV method: KFold, Metric: f1_macro, Score: 0.547250
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.569475
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.570009
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.557726
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.543722
# CV method: KFold, Metric: accuracy, Score: 0.579502
# CV method: KFold, Metric: precision_macro, Score: 0.580282
# CV method: KFold, Metric: recall_macro, Score: 0.568913
# CV method: KFold, Metric: f1_macro, Score: 0.558577
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.579028
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.581990
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.567004
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.552465
# CV method: KFold, Metric: accuracy, Score: 0.577299
# CV method: KFold, Metric: precision_macro, Score: 0.575521
# CV method: KFold, Metric: recall_macro, Score: 0.568978
# CV method: KFold, Metric: f1_macro, Score: 0.563441
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.576192
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.574632
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.567225
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.560606
# CV method: KFold, Metric: accuracy, Score: 0.583411
# CV method: KFold, Metric: precision_macro, Score: 0.582420
# CV method: KFold, Metric: recall_macro, Score: 0.574693
# CV method: KFold, Metric: f1_macro, Score: 0.568719
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.585145
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.584445
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.576467
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.570423
# Random Forest:
# CV method: KFold, Metric: accuracy, Score: 0.560992
# CV method: KFold, Metric: precision_macro, Score: 0.587488
# CV method: KFold, Metric: recall_macro, Score: 0.539845
# CV method: KFold, Metric: f1_macro, Score: 0.478480
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.564125
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.581350
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.545213
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.498529
# CV method: KFold, Metric: accuracy, Score: 0.559471
# CV method: KFold, Metric: precision_macro, Score: 0.595216
# CV method: KFold, Metric: recall_macro, Score: 0.537032
# CV method: KFold, Metric: f1_macro, Score: 0.465217
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.561683
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.591798
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.540153
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.475998
# CV method: KFold, Metric: accuracy, Score: 0.560375
# CV method: KFold, Metric: precision_macro, Score: 0.600557
# CV method: KFold, Metric: recall_macro, Score: 0.537653
# CV method: KFold, Metric: f1_macro, Score: 0.463630
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.561414
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.597544
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.539209
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.469655
# CV method: KFold, Metric: accuracy, Score: 0.582690
# CV method: KFold, Metric: precision_macro, Score: 0.590904
# CV method: KFold, Metric: recall_macro, Score: 0.568648
# CV method: KFold, Metric: f1_macro, Score: 0.547966
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.585754
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.595349
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.571597
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.550523
# CV method: KFold, Metric: accuracy, Score: 0.586888
# CV method: KFold, Metric: precision_macro, Score: 0.598824
# CV method: KFold, Metric: recall_macro, Score: 0.572073
# CV method: KFold, Metric: f1_macro, Score: 0.548936
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.588138
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.600616
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.573324
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.550171
# CV method: KFold, Metric: accuracy, Score: 0.587976
# CV method: KFold, Metric: precision_macro, Score: 0.601577
# CV method: KFold, Metric: recall_macro, Score: 0.572802
# CV method: KFold, Metric: f1_macro, Score: 0.548361
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.588630
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.603052
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.573334
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.548390
# XGBoost:
# CV method: KFold, Metric: accuracy, Score: 0.561525
# CV method: KFold, Metric: precision_macro, Score: 0.589356
# CV method: KFold, Metric: recall_macro, Score: 0.540471
# CV method: KFold, Metric: f1_macro, Score: 0.479576
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.560733
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.589624
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.539447
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.476580
# CV method: KFold, Metric: accuracy, Score: 0.561544
# CV method: KFold, Metric: precision_macro, Score: 0.589397
# CV method: KFold, Metric: recall_macro, Score: 0.540492
# CV method: KFold, Metric: f1_macro, Score: 0.479614
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.560830
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.592837
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.539220
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.473833
# CV method: KFold, Metric: accuracy, Score: 0.583626
# CV method: KFold, Metric: precision_macro, Score: 0.587523
# CV method: KFold, Metric: recall_macro, Score: 0.571517
# CV method: KFold, Metric: f1_macro, Score: 0.557416
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.582604
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.586096
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.570610
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.556775
# CV method: KFold, Metric: accuracy, Score: 0.587952
# CV method: KFold, Metric: precision_macro, Score: 0.592902
# CV method: KFold, Metric: recall_macro, Score: 0.575728
# CV method: KFold, Metric: f1_macro, Score: 0.561591
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.586190
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.590625
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.574119
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.560209
# CV method: KFold, Metric: accuracy, Score: 0.587647
# CV method: KFold, Metric: precision_macro, Score: 0.586994
# CV method: KFold, Metric: recall_macro, Score: 0.579046
# CV method: KFold, Metric: f1_macro, Score: 0.573444
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.587576
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.587341
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.578722
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.572445
# CV method: KFold, Metric: accuracy, Score: 0.591735
# CV method: KFold, Metric: precision_macro, Score: 0.591551
# CV method: KFold, Metric: recall_macro, Score: 0.583118
# CV method: KFold, Metric: f1_macro, Score: 0.577594
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.591314
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.591614
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.582378
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.576146
# CV method: KFold, Metric: accuracy, Score: 0.564018
# CV method: KFold, Metric: precision_macro, Score: 0.597027
# CV method: KFold, Metric: recall_macro, Score: 0.542532
# CV method: KFold, Metric: f1_macro, Score: 0.479124
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.564537
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.597916
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.543110
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.480075
# CV method: KFold, Metric: accuracy, Score: 0.568068
# CV method: KFold, Metric: precision_macro, Score: 0.602328
# CV method: KFold, Metric: recall_macro, Score: 0.546979
# CV method: KFold, Metric: f1_macro, Score: 0.487235
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.568723
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.602905
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.547730
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.488745
# CV method: KFold, Metric: accuracy, Score: 0.593209
# CV method: KFold, Metric: precision_macro, Score: 0.599096
# CV method: KFold, Metric: recall_macro, Score: 0.581109
# CV method: KFold, Metric: f1_macro, Score: 0.567583
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.593111
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.598780
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.581090
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.567811
# CV method: KFold, Metric: accuracy, Score: 0.597359
# CV method: KFold, Metric: precision_macro, Score: 0.604174
# CV method: KFold, Metric: recall_macro, Score: 0.585266
# CV method: KFold, Metric: f1_macro, Score: 0.571991
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.598421
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.605314
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.586390
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.573349
# CV method: KFold, Metric: accuracy, Score: 0.598142
# CV method: KFold, Metric: precision_macro, Score: 0.598521
# CV method: KFold, Metric: recall_macro, Score: 0.589625
# CV method: KFold, Metric: f1_macro, Score: 0.584437
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.599404
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.600081
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.590789
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.585438
# CV method: KFold, Metric: accuracy, Score: 0.605602
# CV method: KFold, Metric: precision_macro, Score: 0.606506
# CV method: KFold, Metric: recall_macro, Score: 0.597283
# CV method: KFold, Metric: f1_macro, Score: 0.592608
# CV method: StratifiedKFold, Metric: accuracy, Score: 0.606328
# CV method: StratifiedKFold, Metric: precision_macro, Score: 0.607313
# CV method: StratifiedKFold, Metric: recall_macro, Score: 0.598023
# CV method: StratifiedKFold, Metric: f1_macro, Score: 0.593375
